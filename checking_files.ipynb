# %%
import os

# %%
folder_paths_2 = [
    "/Users/christoffer/Downloads/new_spinal_cord_data_CG/slide20/region_7d-1",
    "/Users/christoffer/Downloads/new_spinal_cord_data_CG/slide20/region_7d-2",
    "/Users/christoffer/Downloads/new_spinal_cord_data_CG/slide20/region_9d-1",
    "/Users/christoffer/Downloads/new_spinal_cord_data_CG/slide20/region_9d-2",
    "/Users/christoffer/Downloads/new_spinal_cord_data_CG/slide20/region_9d-3",
    "/Users/christoffer/Downloads/new_spinal_cord_data_CG/slide21-DD-d3d4d14liver-d14myelin/region_liver-d14-1",
    "/Users/christoffer/Downloads/new_spinal_cord_data_CG/slide21-DD-d3d4d14liver-d14myelin/region_liver-d3-1",
    "/Users/christoffer/Downloads/new_spinal_cord_data_CG/slide21-DD-d3d4d14liver-d14myelin/region_liver-d3-2",
    "/Users/christoffer/Downloads/new_spinal_cord_data_CG/slide21-DD-d3d4d14liver-d14myelin/region_liver-d3-3",
    "/Users/christoffer/Downloads/new_spinal_cord_data_CG/slide21-DD-d3d4d14liver-d14myelin/region_liver-d4-1",
    "/Users/christoffer/Downloads/new_spinal_cord_data_CG/slide21-DD-d3d4d14liver-d14myelin/region_liver-d4-2",
    "/Users/christoffer/Downloads/new_spinal_cord_data_CG/slide21-DD-d3d4d14liver-d14myelin/region_myelin-d14-1",
    "/Users/christoffer/Downloads/new_spinal_cord_data_CG/slide21-DD-d3d4d14liver-d14myelin/region_myelin-d14-2",
    "/Users/christoffer/Downloads/new_spinal_cord_data_CG/slide21-DD-d3d4d14liver-d14myelin/region_myelin-d14-3",
    "/Users/christoffer/Downloads/new_spinal_cord_data_CG/slide21-DD-d3d4d14liver-d14myelin/region_myelin-d14-4"
]

# %%
for folder in folder_paths_2:
    print(folder)
    print(os.listdir(folder))
# Out:
# /Users/christoffer/Downloads/new_spinal_cord_data_CG/slide20/region_7d-1
# ['.DS_Store', 'm50_s4', 'detected_transcripts_baysor_cleaned.csv', 'detected_transcripts_baysor.csv', 'detected_transcripts_baysor_baysor_cleaned.csv', 'baysor_m50_scale4', 'detected_transcripts.csv', 'detected_transcripts_cleaned.csv', 'detected_transcripts_baysor_baysor.csv']
# /Users/christoffer/Downloads/new_spinal_cord_data_CG/slide20/region_7d-2
# ['detected_transcripts_baysor_cleaned.csv', 'detected_transcripts_baysor.csv', 'baysor_m50_scale4', 'detected_transcripts.csv', 'detected_transcripts_cleaned.csv']
# /Users/christoffer/Downloads/new_spinal_cord_data_CG/slide20/region_9d-1
# ['detected_transcripts.csv', 'detected_transcripts_cleaned.csv']
# /Users/christoffer/Downloads/new_spinal_cord_data_CG/slide20/region_9d-2
# ['detected_transcripts.csv', 'detected_transcripts_cleaned.csv']
# /Users/christoffer/Downloads/new_spinal_cord_data_CG/slide20/region_9d-3
# ...
